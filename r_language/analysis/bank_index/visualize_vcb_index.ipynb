# %% [markdown]
# # Import modules

# %%
library(ggplot2)

# %%
install.packages("dplyr")
install.packages("tidyr")

library(dplyr)
library(tidyr)
# Out:
# Installing package into ‘/usr/local/lib/R/site-library’
# (as ‘lib’ is unspecified)
#
# Installing package into ‘/usr/local/lib/R/site-library’
# (as ‘lib’ is unspecified)
#
#
# Attaching package: ‘dplyr’
#
#
# The following objects are masked from ‘package:stats’:
#
#     filter, lag
#
#
# The following objects are masked from ‘package:base’:
#
#     intersect, setdiff, setequal, union

# %%
library(scales)

# %% [markdown]
# # Load data

# %%
vcb_kqkd <- read.csv("./dataset/clean_dataset/bank_index/vcb/vcb_kqkd.csv")
head(vcb_kqkd, 5)
# Out:
#   Năm  Kỳ Doanh.thu..đồng. Tăng.trưởng.doanh.thu....
# 1 2024 4  2.358126e+13     -0.06042480
# 2 2024 3  2.319121e+13     -0.12526943
# 3 2024 2  2.286271e+13     -0.20676776
# 4 2024 1  2.401966e+13     -0.13254703
# 5 2023 4  2.509779e+13     -0.01708681
#   Lợi.nhuận.sau.thuế.của.Cổ.đông.công.ty.mẹ..đồng. Tăng.trưởng.lợi.nhuận....
# 1 8.565378e+12                                     -0.08440896
# 2 8.566598e+12                                      0.17852434
# 3 8.119414e+12                                      0.09384448
# 4 8.579996e+12                                     -0.04522806
# 5 9.355026e+12                                     -0.05773922
#   LN.trước.thuế Lợi.nhuận.thuần Cố.tức.đã.nhận
# 1 1.070268e+13  8.569921e+12    6.63780e+10
# 2 1.069894e+13  8.572494e+12    4.93960e+10
# 3 1.011628e+13  8.124709e+12    1.59132e+11
# 4 1.071824e+13  8.585993e+12    3.22730e+10
# 5 1.169350e+13  9.360033e+12    5.05480e+10

# %%
vcb_cstc <- read.csv("./dataset/clean_dataset/bank_index/vcb/vcb_cstc.csv")
head(vcb_cstc, 5)
# Out:
#   CP  Năm  Kỳ Biên.lợi.nhuận.ròng.... ROE....   ROIC.... ROA....
# 1 VCB 2024 4  0.6187814               0.1873164 0        0.01723679
# 2 VCB 2024 3  0.6309344               0.1939127 0        0.01858614
# 3 VCB 2024 2  0.5838066               0.1951291 0        0.01838560
# 4 VCB 2024 1  0.6094589               0.1997347 0        0.01851554
# 5 VCB 2023 4  0.7307915               0.2197388 0        0.01808340
#   Tỷ.suất.cổ.tức.... Vốn.hóa..Tỷ.đồng. Số.CP.lưu.hành..Triệu.CP. P.E
# 1 0                  5.013405e+14      8355675094                14.81880
# 2 0                  5.125197e+14      5589091262                14.80371
# 3 0                  5.108429e+14      5589091262                15.32988
# 4 0                  4.896044e+14      5589091262                15.00622
# 5 0                  5.287280e+14      5589091262                16.00596
#   P.B      P.S      P.Cash.Flow EPS..VND. BVPS..VND.
# 1 2.556387 7.310462   8.479643  1025.097  23470.62
# 2 2.694830 7.669374 -10.421608  1532.735  34028.11
# 3 2.813058 7.767334 123.346014  1452.725  32491.34
# 4 2.821707 7.363946  -3.257646  1535.133  31045.04
# 5 3.205992 7.807162 -13.718398  1673.801  29507.24

# %%
vcb_cdtc <- read.csv("./dataset/clean_dataset/bank_index/vcb/vcb_cdtc.csv")
head(vcb_cdtc, 5)
# Out:
#   Năm  Kỳ TỔNG.CỘNG.TÀI.SẢN..đồng. TỔNG.CỘNG.NGUỒN.VỐN..đồng.
# 1 2024 4  2.085874e+15             2.085874e+15
# 2 2024 3  1.932362e+15             1.932362e+15
# 3 2024 2  1.905639e+15             1.905639e+15
# 4 2024 1  1.773714e+15             1.773714e+15
# 5 2023 4  1.839223e+15             1.839223e+15
#   NỢ.PHẢI.TRẢ..đồng. VỐN.CHỦ.SỞ.HỮU..đồng. LỢI.ÍCH.CỦA.CỔ.ĐÔNG.THIỂU.SỐ
# 1 1.889664e+15       1.962092e+14          9.62610e+10
# 2 1.742065e+15       1.902970e+14          1.10763e+11
# 3 1.723936e+15       1.817028e+14          1.05738e+11
# 4 1.600099e+15       1.736141e+14          1.00556e+11
# 5 1.670680e+15       1.685433e+14          9.39900e+10

# %% [markdown]
# # Perform descriptive statistics

# %%
summary(vcb_kqkd)
# Out:
#       Năm             Kỳ        Doanh.thu..đồng.    Tăng.trưởng.doanh.thu....
#  Min.   :2021   Min.   :1.000   Min.   :1.794e+13   Min.   :-0.20677
#  1st Qu.:2022   1st Qu.:2.000   1st Qu.:2.257e+13   1st Qu.:-0.06042
#  Median :2023   Median :3.000   Median :2.358e+13   Median : 0.12424
#  Mean   :2023   Mean   :2.615   Mean   :2.368e+13   Mean   : 0.11459
#  3rd Qu.:2024   3rd Qu.:4.000   3rd Qu.:2.553e+13   3rd Qu.: 0.27945
#  Max.   :2024   Max.   :4.000   Max.   :2.882e+13   Max.   : 0.43188
#  Lợi.nhuận.sau.thuế.của.Cổ.đông.công.ty.mẹ..đồng. Tăng.trưởng.lợi.nhuận....
#  Min.   :5.937e+12                                Min.   :-0.08441
#  1st Qu.:7.269e+12                                1st Qu.: 0.09384
#  Median :8.119e+12                                Median : 0.15391
#  Mean   :7.946e+12                                Mean   : 0.17749
#  3rd Qu.:8.580e+12                                3rd Qu.: 0.25027
#  Max.   :9.928e+12                                Max.   : 0.51813
#  LN.trước.thuế       Lợi.nhuận.thuần     Cố.tức.đã.nhận
#  Min.   :7.423e+12   Min.   :5.942e+12   Min.   :2.434e+10
#  1st Qu.:9.051e+12   1st Qu.:7.275e+12   1st Qu.:3.111e+10
#  Median :1.012e+13   Median :8.125e+12   Median :3.953e+10
#  Mean   :9.924e+12   Mean   :7.951e+12   Mean   :6.255e+10
#  3rd Qu.:1.072e+13   3rd Qu.:8.586e+12   3rd Qu.:6.638e+10
#  Max.   :1.242e+13   Max.   :9.934e+12   Max.   :1.591e+11

# %%
summary(vcb_cstc)
# Out:
#       CP                 Năm             Kỳ        Biên.lợi.nhuận.ròng....
#  Length:13          Min.   :2021   Min.   :1.000   Min.   :0.4439
#  Class :character   1st Qu.:2022   1st Qu.:2.000   1st Qu.:0.5771
#  Mode  :character   Median :2023   Median :3.000   Median :0.6131
#                     Mean   :2023   Mean   :2.615   Mean   :0.5976
#                     3rd Qu.:2024   3rd Qu.:4.000   3rd Qu.:0.6327
#                     Max.   :2024   Max.   :4.000   Max.   :0.7308
#     ROE....          ROIC....    ROA....        Tỷ.suất.cổ.tức....
#  Min.   :0.1873   Min.   :0   Min.   :0.01599   Min.   :0
#  1st Qu.:0.1997   1st Qu.:0   1st Qu.:0.01724   1st Qu.:0
#  Median :0.2165   Median :0   Median :0.01808   Median :0
#  Mean   :0.2145   Mean   :0   Mean   :0.01780   Mean   :0
#  3rd Qu.:0.2263   3rd Qu.:0   3rd Qu.:0.01852   3rd Qu.:0
#  Max.   :0.2443   Max.   :0   Max.   :0.01894   Max.   :0
#  Vốn.hóa..Tỷ.đồng.   Số.CP.lưu.hành..Triệu.CP.      P.E             P.B
#  Min.   :3.147e+14   Min.   :4.733e+09         Min.   :12.62   Min.   :2.556
#  1st Qu.:4.060e+14   1st Qu.:4.733e+09         1st Qu.:14.79   1st Qu.:2.813
#  Median :4.896e+14   Median :5.589e+09         Median :14.83   Median :3.086
#  Mean   :4.518e+14   Mean   :5.407e+09         Mean   :15.05   Mean   :3.000
#  3rd Qu.:5.013e+14   3rd Qu.:5.589e+09         3rd Qu.:15.37   3rd Qu.:3.165
#  Max.   :5.287e+14   Max.   :8.356e+09         Max.   :17.47   Max.   :3.512
#       P.S         P.Cash.Flow        EPS..VND.      BVPS..VND.
#  Min.   :5.174   Min.   :-22.191   Min.   :1025   Min.   :23039
#  1st Qu.:6.316   1st Qu.: -6.989   1st Qu.:1301   1st Qu.:25968
#  Median :7.039   Median :  2.281   Median :1453   Median :28473
#  Mean   :6.847   Mean   :  8.384   Mean   :1496   Mean   :28171
#  3rd Qu.:7.364   3rd Qu.:  8.228   3rd Qu.:1674   3rd Qu.:30547
#  Max.   :7.807   Max.   :123.346   Max.   :2098   Max.   :34028

# %%
summary(vcb_cdtc)
# Out:
#       Năm             Kỳ        TỔNG.CỘNG.TÀI.SẢN..đồng.
#  Min.   :2021   Min.   :1.000   Min.   :1.415e+15
#  1st Qu.:2022   1st Qu.:2.000   1st Qu.:1.650e+15
#  Median :2023   Median :3.000   Median :1.774e+15
#  Mean   :2023   Mean   :2.615   Mean   :1.751e+15
#  3rd Qu.:2024   3rd Qu.:4.000   3rd Qu.:1.846e+15
#  Max.   :2024   Max.   :4.000   Max.   :2.086e+15
#  TỔNG.CỘNG.NGUỒN.VỐN..đồng. NỢ.PHẢI.TRẢ..đồng.  VỐN.CHỦ.SỞ.HỮU..đồng.
#  Min.   :1.415e+15          Min.   :1.304e+15   Min.   :1.112e+14
#  1st Qu.:1.650e+15          1st Qu.:1.521e+15   1st Qu.:1.284e+14
#  Median :1.774e+15          Median :1.600e+15   Median :1.520e+14
#  Mean   :1.751e+15          Mean   :1.598e+15   Mean   :1.526e+14
#  3rd Qu.:1.846e+15          3rd Qu.:1.702e+15   3rd Qu.:1.736e+14
#  Max.   :2.086e+15          Max.   :1.890e+15   Max.   :1.962e+14
#  LỢI.ÍCH.CỦA.CỔ.ĐÔNG.THIỂU.SỐ
#  Min.   :8.711e+10
#  1st Qu.:9.374e+10
#  Median :9.777e+10
#  Mean   :9.784e+10
#  3rd Qu.:1.022e+11
#  Max.   :1.108e+11

# %% [markdown]
# # Visualize

# %% [markdown]
# ## Kết quả kinh doanh

# %%
vcb_kqkd$Tháng <- vcb_kqkd$Kỳ * 3

# %%
head(vcb_kqkd, 5)
# Out:
#   Năm  Kỳ Doanh.thu..đồng. Tăng.trưởng.doanh.thu....
# 1 2024 4  2.358126e+13     -0.06042480
# 2 2024 3  2.319121e+13     -0.12526943
# 3 2024 2  2.286271e+13     -0.20676776
# 4 2024 1  2.401966e+13     -0.13254703
# 5 2023 4  2.509779e+13     -0.01708681
#   Lợi.nhuận.sau.thuế.của.Cổ.đông.công.ty.mẹ..đồng. Tăng.trưởng.lợi.nhuận....
# 1 8.565378e+12                                     -0.08440896
# 2 8.566598e+12                                      0.17852434
# 3 8.119414e+12                                      0.09384448
# 4 8.579996e+12                                     -0.04522806
# 5 9.355026e+12                                     -0.05773922
#   LN.trước.thuế Lợi.nhuận.thuần Cố.tức.đã.nhận Tháng ThoiGian
# 1 1.070268e+13  8.569921e+12    6.63780e+10    12    2024-12
# 2 1.069894e+13  8.572494e+12    4.93960e+10     9    2024-9
# 3 1.011628e+13  8.124709e+12    1.59132e+11     6    2024-6
# 4 1.071824e+13  8.585993e+12    3.22730e+10     3    2024-3
# 5 1.169350e+13  9.360033e+12    5.05480e+10    12    2023-12

# %%
vcb_kqkd$ThoiGian <- as.Date(paste0(vcb_kqkd$Năm, "-", vcb_kqkd$Tháng, "-01"))

ggplot(vcb_kqkd, aes(x = ThoiGian, y = Doanh.thu..đồng.)) +
  geom_line(group = 1, color = "steelblue") +
  geom_point(color = "darkblue") +
  labs(
    title = "Doanh thu (đồng) theo thời gian",
    x = "Năm - Kỳ",
    y = "Doanh thu (đồng)"
  ) +
  theme_minimal() +
  theme(axis.text.x = element_text(angle = 45, hjust = 1))
# Out:
# plot without title

# %% [markdown]
# Theo biểu đồ, ta thấy:
#   - Từ đầu năm 2022 đến quý 2 năm 2023, doanh thu có xu hướng tăng và đạt đỉnh ở quý 2 năm 2023.
#   - Sau quý 2 năm 2023, doanh thu giảm dần, sau đó phục hồi dần từ quý 2 năm 2024.

# %%
vcb_kqkd$color <- ifelse(vcb_kqkd$Tăng.trưởng.doanh.thu.... > 0, "green", "red")

ggplot(vcb_kqkd, aes(x = ThoiGian, y = Tăng.trưởng.doanh.thu.... , fill = color)) +
  geom_col() +
  scale_fill_identity() +
  labs(
    title = "Tăng trưởng doanh thu (%) theo thời gian",
    x = "Năm - Kỳ",
    y = "Tăng trưởng doanh thu (%)"
  ) +
  theme_minimal() +
  theme(axis.text.x = element_text(angle = 45, hjust = 1))
# Out:
# plot without title

# %% [markdown]
# Theo biểu đồ tăng trưởng doanh thu, ta thấy:
#   - Từ đầu năm 2022 - quý 3 năm 2023, tăng trưởng doanh thu dương. Trong đó, quý 1 năm 2023 tăng trưởng doanh thu đạt đỉnh.
#   - Trong năm 2022, tăng trưởng doanh thu có xu hướng tăng.
#   - Từ năm 2023, tăng trưởng doanh thu có xu hướng giảm. Trong đó từ cuối năm 2023 tăng trưởng doanh thu bắt đầu âm và đạt đáy vào quý 2 năm 2024.

# %%
vcb_kqkd$color <- ifelse(vcb_kqkd$Tăng.trưởng.lợi.nhuận.... > 0, "green", "red")

ggplot(vcb_kqkd, aes(x = ThoiGian, y = Tăng.trưởng.lợi.nhuận.... , fill = color)) +
  geom_col() +
  scale_fill_identity() +
  labs(
    title = "Tăng trưởng lợi nhuận (%) theo thời gian",
    x = "Năm - Kỳ",
    y = "Tăng trưởng lợi nhuận (%)"
  ) +
  theme_minimal() +
  theme(axis.text.x = element_text(angle = 45, hjust = 1))
# Out:
# plot without title

# %% [markdown]
# Theo biểu đồ tăng trưởng lợi nhuận, ta thấy:
# - Từ năm 2022 đến quý 3 năm 2023, tăng trưởng lợi nhuận dương, trong đó quý 4 năm 2022 tăng trưởng đạt đỉnh.
# - Tăng trưởng lợi nhuận từ năm 2023 có xu hướng giảm, trong đó từ cuối năm 2023 đến đầu năm 2024 tăng trưởng âm.
# - Tăng trưởng lợi nhuận đạt đáy vào cuối năm 2024.

# %%
data_long <- vcb_kqkd %>%
  pivot_longer(cols = c(LN.trước.thuế, Lợi.nhuận.thuần),
              names_to = "Variable",
              values_to = "Value")

ggplot(data_long, aes(x = ThoiGian, y = Value, color = Variable)) +
  geom_line() +
  labs(title = "Lợi nhuận trước thuế và lợi nhuận thuần theo thời gian", x = "Năm - Kỳ", y = "Giá trị (đồng)") +
  theme_minimal()
# Out:
# plot without title

# %% [markdown]
# Theo biểu đồ, ta thấy:
#   - Quý 1/2022 - Quý 1/2023: LN trước thuế có sự biến động lớn. Ban đầu ở mức khoảng 100 nghìn tỷ đồng, sau đó giảm xuống mức thấp nhất khoảng 74 nghìn tỷ đồng vào giữa năm 2022, rồi tăng vọt lên mức cao nhất khoảng 124 nghìn tỷ đồng vào đầu năm 2023.
#   - Quý 2/2023 - Quý 1/2025: Sau khi đạt đỉnh, LN trước thuế giảm xuống còn khoảng 92 nghìn tỷ đồng, sau đó tăng lên rồi lại giảm xuống, và cuối cùng có xu hướng tăng trở lại, đạt khoảng 107 nghìn tỷ đồng vào cuối kỳ.

# %%
vcb_kqkd$color <- ifelse(vcb_kqkd$Cố.tức.đã.nhận > 0, "green", "red")

ggplot(vcb_kqkd, aes(x = ThoiGian, y = Cố.tức.đã.nhận , fill = color)) +
  geom_col() +
  scale_fill_identity() +
  labs(
    title = "Cổ tức đã nhận theo thời gian",
    x = "Năm - Kỳ",
    y = "Cổ tức đã nhận"
  ) +
  theme_minimal() +
  theme(axis.text.x = element_text(angle = 45, hjust = 1))
# Out:
# plot without title

# %% [markdown]
# Theo biểu đồ, ta thấy cổ tức đã nhận có tính chu kì, luôn tăng cao vào quý 3 hàng năm.

# %% [markdown]
# ## Cân đối kế toán

# %%
vcb_cdtc$Tháng <- vcb_cdtc$Kỳ * 3
head(vcb_cdtc, 5)
# Out:
#   Năm  Kỳ TỔNG.CỘNG.TÀI.SẢN..đồng. TỔNG.CỘNG.NGUỒN.VỐN..đồng.
# 1 2024 4  2.085874e+15             2.085874e+15
# 2 2024 3  1.932362e+15             1.932362e+15
# 3 2024 2  1.905639e+15             1.905639e+15
# 4 2024 1  1.773714e+15             1.773714e+15
# 5 2023 4  1.839223e+15             1.839223e+15
#   NỢ.PHẢI.TRẢ..đồng. VỐN.CHỦ.SỞ.HỮU..đồng. LỢI.ÍCH.CỦA.CỔ.ĐÔNG.THIỂU.SỐ Tháng
# 1 1.889664e+15       1.962092e+14          9.62610e+10                  12
# 2 1.742065e+15       1.902970e+14          1.10763e+11                   9
# 3 1.723936e+15       1.817028e+14          1.05738e+11                   6
# 4 1.600099e+15       1.736141e+14          1.00556e+11                   3
# 5 1.670680e+15       1.685433e+14          9.39900e+10                  12

# %%
vcb_cdtc$ThoiGian <- as.Date(paste0(vcb_cdtc$Năm, "-", vcb_cdtc$Tháng, "-01"))

data_long <- vcb_cdtc %>%
  pivot_longer(cols = c(TỔNG.CỘNG.TÀI.SẢN..đồng., NỢ.PHẢI.TRẢ..đồng.),
              names_to = "Variable",
              values_to = "Value")

ggplot(data_long, aes(x = ThoiGian, y = Value, color = Variable)) +
  geom_line() +
  labs(title = "Tổng cộng tài sản và nợ phải trả theo thời gian", x = "Năm - Kỳ", y = "Giá trị (đồng)") +
  theme_minimal()
# Out:
# plot without title

# %% [markdown]
# Theo biểu đồ, ta thấy:
#   - Tổng cộng tài sản và nợ phải trả có xu hướng tăng dần.
#   - Vào quý 2 năm 2023 và quý 1 năm 2024 có xu hướng giảm nhưng sau đó hồi phục trở lại.

# %%
vcb_cdtc$ThoiGian <- as.Date(paste0(vcb_cdtc$Năm, "-", vcb_cdtc$Tháng, "-01"))

data_long <- vcb_cdtc %>%
  pivot_longer(cols = c(VỐN.CHỦ.SỞ.HỮU..đồng.),
              names_to = "Variable",
              values_to = "Value")

ggplot(data_long, aes(x = ThoiGian, y = Value, color = Variable)) +
  geom_line() +
  labs(title = "Vốn chủ sở hữu theo thời gian", x = "Năm - Kỳ", y = "Vốn chủ sở hữu (đồng)") +
  theme_minimal()
# Out:
# plot without title

# %% [markdown]
# Theo biểu đồ, ta thấy vốn chủ sở hữu tăng dần theo thời gian.

# %%
vcb_cdtc$ThoiGian <- as.Date(paste0(vcb_cdtc$Năm, "-", vcb_cdtc$Tháng, "-01"))

data_long <- vcb_cdtc %>%
  pivot_longer(cols = c(LỢI.ÍCH.CỦA.CỔ.ĐÔNG.THIỂU.SỐ),
              names_to = "Variable",
              values_to = "Value")

ggplot(data_long, aes(x = ThoiGian, y = Value, color = Variable)) +
  geom_line() +
  labs(title = "Lợi ích của cổ đông thiểu số theo thời gian", x = "Năm - Kỳ", y = "Lợi ích của cổ đông thiểu số") +
  theme_minimal()
# Out:
# plot without title

# %% [markdown]
# Theo biểu đồ, ta thấy lợi ích cổ đông thiểu số có tính chu kì và tăng dần theo thời gian.

# %% [markdown]
# ## Chỉ số tài chính

# %%
vcb_cstc$Tháng <- vcb_cstc$Kỳ * 3
head(vcb_cstc, 5)
# Out:
#   CP  Năm  Kỳ Biên.lợi.nhuận.ròng.... ROE....   ROIC.... ROA....
# 1 VCB 2024 4  0.6187814               0.1873164 0        0.01723679
# 2 VCB 2024 3  0.6309344               0.1939127 0        0.01858614
# 3 VCB 2024 2  0.5838066               0.1951291 0        0.01838560
# 4 VCB 2024 1  0.6094589               0.1997347 0        0.01851554
# 5 VCB 2023 4  0.7307915               0.2197388 0        0.01808340
#   Tỷ.suất.cổ.tức.... Vốn.hóa..Tỷ.đồng. Số.CP.lưu.hành..Triệu.CP. P.E
# 1 0                  5.013405e+14      8355675094                14.81880
# 2 0                  5.125197e+14      5589091262                14.80371
# 3 0                  5.108429e+14      5589091262                15.32988
# 4 0                  4.896044e+14      5589091262                15.00622
# 5 0                  5.287280e+14      5589091262                16.00596
#   P.B      P.S      P.Cash.Flow EPS..VND. BVPS..VND. Tháng
# 1 2.556387 7.310462   8.479643  1025.097  23470.62   12
# 2 2.694830 7.669374 -10.421608  1532.735  34028.11    9
# 3 2.813058 7.767334 123.346014  1452.725  32491.34    6
# 4 2.821707 7.363946  -3.257646  1535.133  31045.04    3
# 5 3.205992 7.807162 -13.718398  1673.801  29507.24   12

# %%
vcb_cstc$ThoiGian <- as.Date(paste0(vcb_cstc$Năm, "-", vcb_cstc$Tháng, "-01"))

scale_factor <- max(vcb_cstc$ROE...., na.rm = TRUE) / max(vcb_cstc$ROA...., na.rm = TRUE)

ggplot(vcb_cstc, aes(x = ThoiGian)) +
  geom_line(aes(y = ROE...., color = "ROE (%)"), size = 1) +
  geom_point(aes(y = ROE...., color = "ROE (%)")) +
  geom_line(aes(y = ROA.... * scale_factor, color = "ROA (%)"), size = 1) +
  geom_point(aes(y = ROA.... * scale_factor, color = "ROA (%)")) +
  scale_y_continuous(
    name = "ROE (%)",
    sec.axis = sec_axis(~ . / scale_factor, name = "ROA (%)")
  ) +
  scale_color_manual(
    name = "",
    values = c("ROE (%)" = "#1f77b4", "ROA (%)" = "#ff7f0e")
  ) +
  labs(
    title = "ROE và ROA theo thời gian",
    x = "Năm - Kỳ"
  ) +
  theme_minimal() +
  theme(
    axis.text.x = element_text(angle = 45, hjust = 1),
    legend.position = "top"
  )
# Out:
# plot without title

# %% [markdown]
# Đối với ROE:
# - Từ 2022: ROE có xu hướng tăng trưởng đáng kể trong suốt năm 2022, đạt đỉnh vào khoảng cuối năm 2022.
# - Năm 2023 - 2024: Sau khi đạt đỉnh, ROE lại có xu hướng giảm mạnh.
#
# Đối với ROA:
# - Đầu năm 2022: ROA cũng cho thấy sự tăng trưởng nhẹ.
# - Từ cuối năm 2022 - 2024: ROA có xu hướng chu kỳ, sau đó giảm mạnh vào cuối năm 2024.
#
# Công ty  ban đầu dùng đòn bẩy tài chính hợp lý, nhưng về sau có dấu hiệu mất kiểm soát tài chính hoặc lợi nhuận sụt giảm trong khi nợ vẫn cao (do ROE tụt xuống dưới ROA).

# %%
vcb_cstc$color <- ifelse(vcb_cstc$Biên.lợi.nhuận.ròng.... > 0, "green", "red")

ggplot(vcb_cstc, aes(x = ThoiGian, y = Biên.lợi.nhuận.ròng.... , fill = color)) +
  geom_col() +
  scale_fill_identity() +
  labs(
    title = "Biên lợi nhuận ròng (%) theo thời gian",
    x = "Năm - Kỳ",
    y = "Biên lợi nhuận ròng (%)"
  ) +
  theme_minimal() +
  theme(axis.text.x = element_text(angle = 45, hjust = 1))
# Out:
# plot without title

# %% [markdown]
# Theo biểu đồ, ta thấy:
# - Quý 4 năm 2023: Biên lợi nhuận ròng đạt mức cao nhất.
# - Quý 3 năm 2022: Mức biên lợi nhuận ròng thấp nhất.
# - Không có xu hướng rõ ràng: Nhìn chung, không có một xu hướng tăng hoặc giảm rõ rệt nào của biên lợi nhuận ròng trong suốt giai đoạn này. Thay vào đó, nó dao động lên xuống đáng kể.

# %%
vcb_cstc$ThoiGian <- as.Date(paste0(vcb_cstc$Năm, "-", vcb_cstc$Tháng, "-01"))

data_long <- vcb_cstc %>%
  pivot_longer(cols = c(Vốn.hóa..Tỷ.đồng.),
              names_to = "Variable",
              values_to = "Value")

ggplot(data_long, aes(x = ThoiGian, y = Value, color = Variable)) +
  geom_line() +
  labs(title = "Vốn hóa (tỷ đồng) theo thời gian", x = "Năm - Kỳ", y = "Vốn hóa (tỷ đồng)") +
  theme_minimal()
# Out:
# plot without title

# %% [markdown]
# Theo biểu đồ, ta thấy:
# - Vốn hóa có xu hướng tăng dần từ năm 2022 - 2024.
# - Quý 2 năm 2022, quý 2 năm 2023 và quý 1 năm 2024: vốn hóa có giảm nhẹ nhưng sau đó phục hồi trở lại.

# %%
vcb_cstc$color <- ifelse(vcb_cstc$Số.CP.lưu.hành..Triệu.CP. > 0, "green", "red")

ggplot(vcb_cstc, aes(x = ThoiGian, y = Số.CP.lưu.hành..Triệu.CP. , fill = color)) +
  geom_col() +
  scale_fill_identity() +
  labs(
    title = "Số cổ phiếu lưu hành (triệu cổ phiếu) theo thời gian",
    x = "Năm - Kỳ",
    y = "Số cổ phiếu lưu hành (triệu cổ phiếu)"
  ) +
  theme_minimal() +
  theme(axis.text.x = element_text(angle = 45, hjust = 1))
# Out:
# plot without title

# %% [markdown]
# Từ biểu đồ, số cổ phiếu lưu hành có 2 lần điều chỉnh vào quý 2 năm 2023 và quý 4 năm 2024.

# %%
vcb_cstc$ThoiGian <- as.Date(paste0(vcb_cstc$Năm, "-", vcb_cstc$Tháng, "-01"))

scale_factor <- max(vcb_cstc$BVPS..VND., na.rm = TRUE) / max(vcb_cstc$EPS..VND., na.rm = TRUE)

ggplot(vcb_cstc, aes(x = ThoiGian)) +
  geom_col(aes(y = BVPS..VND., fill = "BVPS"), width = 25) +
  geom_line(aes(y = EPS..VND. * scale_factor, color = "EPS"), size = 1.2) +
  geom_point(aes(y = EPS..VND. * scale_factor, color = "EPS")) +
  scale_y_continuous(
    name = "BVPS (VND)",
    sec.axis = sec_axis(~ . / scale_factor, name = "EPS (VND)")
  ) +
  scale_fill_manual(values = c("BVPS" = "skyblue"), name = "") +
  scale_color_manual(values = c("EPS" = "darkorange"), name = "") +
  labs(
    title = "BVPS và EPS theo thời gian",
    x = "Thời gian"
  ) +
  theme_minimal() +
  theme(
    axis.text.x = element_text(angle = 45, hjust = 1),
    legend.position = "top"
  )
# Out:
# plot without title

# %% [markdown]
# Về BVPS:
# - BVPS có xu hướng tăng nhẹ theo chu kỳ.
# - Mức tăng/giảm không quá lớn nhưng cho thấy giá trị tài sản ròng trên mỗi cổ phiếu có xu hướng đi lên.
#
# Về EPS:
# - EPS có sự biến động đáng kể hơn so với BVPS.
# - Từ năm 2022, EPS có sự biến động mạnh. EPS đạt đỉnh vào khoảng cuối năm 2022.
# - Từ năm 2023 trở đi, EPS có xu hướng giảm dần và đạt đáy vào cuối năm 2024.

# %%
vcb_cstc$ThoiGian <- as.Date(paste0(vcb_cstc$Năm, "-", vcb_cstc$Tháng, "-01"))

data_long <- vcb_cstc %>%
  pivot_longer(cols = c(P.E),
              names_to = "Variable",
              values_to = "Value")

ggplot(data_long, aes(x = ThoiGian, y = Value, color = Variable)) +
  geom_line() +
  labs(title = "P/E theo thời gian") +
  theme_minimal()

data_long <- vcb_cstc %>%
  pivot_longer(cols = c(P.B),
              names_to = "Variable",
              values_to = "Value")

ggplot(data_long, aes(x = ThoiGian, y = Value, color = Variable)) +
  geom_line() +
  labs(title = "P/B theo thời gian") +
  theme_minimal()

data_long <- vcb_cstc %>%
  pivot_longer(cols = c(P.S),
              names_to = "Variable",
              values_to = "Value")

ggplot(data_long, aes(x = ThoiGian, y = Value, color = Variable)) +
  geom_line() +
  labs(title = "P/S theo thời gian") +
  theme_minimal()
# Out:
# plot without title
# plot without title
# plot without title

# %% [markdown]
# Nhận xét về biểu đồ P/E:
# - Biến động: Tỷ số P/E có sự biến động khá lớn trong giai đoạn này.
# - Đỉnh và đáy: Có thể thấy nhiều đỉnh và đáy, cho thấy sự thay đổi trong kỳ vọng của thị trường về lợi nhuận của công ty.
# - Xu hướng chung: Không có một xu hướng tăng hoặc giảm rõ rệt trong toàn bộ giai đoạn, mà là sự dao động lên xuống. Tuy nhiên, có vẻ như P/E có xu hướng tăng nhẹ vào cuối giai đoạn được thể hiện.
#
# Nhận xét về biểu đồ P/B:
# - Biến động: Tỷ số P/B cũng cho thấy sự biến động, nhưng có vẻ ít hơn so với P/E.
# - Tăng trưởng và giảm: P/B có xu hướng tăng từ giữa năm 2022 và đạt đỉnh đầu năm 2023, sau đó giảm mạnh và đạt đáy vào cuối năm 2024.
#
# Nhận xét về biểu đồ P/S:
# - Xu hướng tăng rõ rệt: Tỷ số P/S cho thấy một xu hướng tăng khá rõ rệt từ giữa năm 2022 đến năm 2024.
# - Ổn định vào năm 2024: Tỷ số P/S loanh quanh ở giá trị 7.5
#
# Trong khi P/S có xu hướng tăng, P/E và P/B lại cho thấy sự biến động với các đỉnh và đáy khác nhau. Điều này có thể phản ánh sự thay đổi trong kỳ vọng của thị trường về các khía cạnh khác nhau của công ty (lợi nhuận, giá trị tài sản, doanh thu).

# %%
vcb_cstc$color <- ifelse(vcb_cstc$P.Cash.Flow > 0, "green", "red")

ggplot(vcb_cstc, aes(x = ThoiGian, y = P.Cash.Flow , fill = color)) +
  geom_col() +
  scale_fill_identity() +
  labs(
    title = "P/Cash Flow theo thời gian",
    x = "Năm - Tháng",
    y = "P/Cash Flow"
  ) +
  theme_minimal() +
  theme(axis.text.x = element_text(angle = 45, hjust = 1))
# Out:
# plot without title

# %% [markdown]
# Dựa trên biểu đồ, ta thấy:
# - Đỉnh điểm bất thường: Vào tháng 6 năm 2024, tỷ số P/Cash Flow tăng vọt lên mức 123.35. Đây là một giá trị rất cao, cho thấy nhà đầu tư sẵn sàng trả một mức giá rất cao cho mỗi đơn vị dòng tiền của công ty vào thời điểm đó. Cần xem xét kỹ lưỡng các yếu tố nào đã dẫn đến sự tăng đột biến này.
# - Xu hướng không rõ ràng: Không có một xu hướng tăng hoặc giảm rõ rệt nào của tỷ số P/Cash Flow trong suốt giai đoạn này, mà là sự biến động thất thường.
