# %%
import os
os.chdir("D:\\UIT\\HK\\HK6\\IS403\\Đồ án\\Source code")
print("Thư mục làm việc hiện tại:", os.getcwd())
# Out:
# Thư mục làm việc hiện tại: D:\UIT\HK\HK6\IS403\Đồ án\Source code

# %%
import warnings
warnings.filterwarnings("ignore")

# %% [markdown]
# # Import modules

# %%
import pandas as pd

# %%
import joblib

# %% [markdown]
# # Load data

# %%
vcb_future = pd.read_csv(".\\dataset\\official_dataset\\vcb\\vcb_future.csv")
vcb_future
# Out:
#                    Time  Close  Previous_GDP  Previous_EUR_Cash  \
# 0   2025-02-18 00:00:00  61.27       1773652           26030.84
# 1   2025-02-19 00:00:00  61.34       1773652           26012.66
# 2   2025-02-20 00:00:00  61.34       1773652           25977.85
# 3   2025-02-21 00:00:00  62.27       1773652           25930.82
# 4   2025-02-24 00:00:00  62.54       1773652           26009.65
# 5   2025-02-25 00:00:00  61.94       1773652           26121.15
# 6   2025-02-26 00:00:00  61.74       1773652           26007.43
# 7   2025-02-27 00:00:00  62.88       1773652           26135.10
# 8   2025-02-28 00:00:00  62.41       1773652           26083.35
# 9   2025-03-03 00:00:00  62.41       1773652           25888.91
# 10  2025-03-04 00:00:00  62.21       1773652           25949.59
# 11  2025-03-05 00:00:00  62.21       1773652           26208.18
# 12  2025-03-06 00:00:00  62.54       1773652           26561.25
# 13  2025-03-07 00:00:00  63.61       1773652           26855.71
# ...

# %%
bid_future = pd.read_csv(".\\dataset\\official_dataset\\bid\\bid_future.csv")
bid_future
# Out:
#                    Time  Close  Previous_GDP  Previous_EUR_Cash  \
# 0   2025-02-18 00:00:00  40.50       1773652            26258.0
# 1   2025-02-19 00:00:00  40.85       1773652            26290.0
# 2   2025-02-20 00:00:00  40.90       1773652            26234.0
# 3   2025-02-21 00:00:00  40.90       1773652            26184.0
# 4   2025-02-24 00:00:00  41.10       1773652            26298.0
# 5   2025-02-25 00:00:00  41.25       1773652            26354.0
# 6   2025-02-26 00:00:00  41.20       1773652            26290.0
# 7   2025-02-27 00:00:00  40.95       1773652            26381.0
# 8   2025-02-28 00:00:00  40.95       1773652            26324.0
# 9   2025-03-03 00:00:00  40.95       1773652            26150.0
# 10  2025-03-04 00:00:00  40.80       1773652            26222.0
# 11  2025-03-05 00:00:00  40.65       1773652            26457.0
# 12  2025-03-06 00:00:00  40.80       1773652            26788.0
# 13  2025-03-07 00:00:00  41.15       1773652            27024.0
# ...

# %%
tcb_future = pd.read_csv(".\\dataset\\official_dataset\\tcb\\tcb_future.csv")
tcb_future
# Out:
#                    Time  Close  Previous_GDP  Previous_EUR_Cash  \
# 0   2025-02-18 00:00:00  25.85       1773652            26059.0
# 1   2025-02-19 00:00:00  26.10       1773652            26068.0
# 2   2025-02-20 00:00:00  26.55       1773652            26010.0
# 3   2025-02-21 00:00:00  26.50       1773652            26020.0
# 4   2025-02-25 00:00:00  26.40       1773652            26054.0
# 5   2025-02-26 00:00:00  26.30       1773652            26099.0
# 6   2025-02-27 00:00:00  26.25       1773652            26170.0
# 7   2025-02-28 00:00:00  26.10       1773652            26150.0
# 8   2025-03-04 00:00:00  27.50       1773652            26096.0
# 9   2025-03-05 00:00:00  27.30       1773652            26235.0
# 10  2025-03-06 00:00:00  27.70       1773652            26710.0
# 11  2025-03-07 00:00:00  27.75       1773652            26913.0
# 12  2025-03-11 00:00:00  28.00       1773652            27079.0
# 13  2025-03-12 00:00:00  27.85       1773652            27173.0
# ...

# %% [markdown]
# # Prepare future price

# %%
vcb_future = vcb_future.drop(columns=["Time", "Close"]).iloc[-1:, :]
vcb_future
# Out:
#     Previous_GDP  Previous_EUR_Cash  Previous_THB_Cash  Previous_USD_Cash  \
# 30       1773652           26979.95             664.95            25350.0
#
#     Tăng trưởng lợi nhuận (%)  Vốn hóa (Tỷ đồng)    BVPS (VND)  \
# 30                  -0.084409    501340505640000  23470.623833
#
#     VỐN CHỦ SỞ HỮU (đồng)
# 30        196209168000000

# %%
bid_future = bid_future.drop(columns=["Time", "Close"]).iloc[-1:, :]
bid_future
# Out:
#     Previous_GDP  Previous_EUR_Cash  Previous_THB_Cash  Previous_USD_Cash  \
# 29       1773652            27224.0             693.15            24370.0
#
#     Tăng trưởng lợi nhuận (%)  Vốn hóa (Tỷ đồng)    BVPS (VND)  \
# 29                   0.285767    256279709970500  20577.535482
#
#     VỐN CHỦ SỞ HỮU (đồng)
# 29        144911113000000

# %%
tcb_future = tcb_future.drop(columns=["Time", "Close"]).iloc[-1:, :]
tcb_future
# Out:
#     Previous_GDP  Previous_EUR_Cash  Previous_THB_Cash  Previous_USD_Cash  \
# 24       1773652            27035.0              670.0            25359.0
#
#     Tăng trưởng lợi nhuận (%)  Vốn hóa (Tỷ đồng)    BVPS (VND)  \
# 24                  -0.240565    183686145214000  20583.468751
#
#     VỐN CHỦ SỞ HỮU (đồng)
# 24        147939621000000

# %% [markdown]
# # Load model

# %%
vcb_sarimax = joblib.load(".\\model_application\\experiment\\saved_checkpoint\\sarimax\\vcb\\sarimax.pkl")
print(vcb_sarimax.summary())
# Out:
#                                SARIMAX Results
# ...
# Dep. Variable:                      y   No. Observations:                  833
# Model:               SARIMAX(1, 0, 0)   Log Likelihood                -971.005
# Date:                Fri, 25 Apr 2025   AIC                           1962.010
# Time:                        21:50:49   BIC                           2009.261
# Sample:                             0   HQIC                          1980.127
#                                 - 833
# Covariance Type:                  opg
# ...
#                                 coef    std err          z      P>|z|      [0.025      0.975]
# ---------------------------------------------------------------------------------------------
# Previous_GDP                3.69e-06   3.52e-23   1.05e+17      0.000    3.69e-06    3.69e-06
# Previous_EUR_Cash             0.0021   7.59e-25   2.72e+21      0.000       0.002       0.002
# ...

# %%
bid_sarimax = joblib.load(".\\model_application\\experiment\\saved_checkpoint\\sarimax\\bid\\sarimax.pkl")
print(bid_sarimax.summary())
# Out:
#                                SARIMAX Results
# ...
# Dep. Variable:                      y   No. Observations:                  777
# Model:               SARIMAX(2, 0, 0)   Log Likelihood                -838.064
# Date:                Fri, 25 Apr 2025   AIC                           1698.129
# Time:                        21:50:49   BIC                           1749.339
# Sample:                             0   HQIC                          1717.829
#                                 - 777
# Covariance Type:                  opg
# ...
#                                 coef    std err          z      P>|z|      [0.025      0.975]
# ---------------------------------------------------------------------------------------------
# Previous_GDP               1.436e-05   5.58e-24   2.57e+18      0.000    1.44e-05    1.44e-05
# Previous_EUR_Cash             0.0031   1.08e-24   2.83e+21      0.000       0.003       0.003
# ...

# %%
tcb_sarimax = joblib.load(".\\model_application\\experiment\\saved_checkpoint\\sarimax\\tcb\\sarimax.pkl")
print(tcb_sarimax.summary())
# Out:
#                                SARIMAX Results
# ...
# Dep. Variable:                      y   No. Observations:                  659
# Model:               SARIMAX(1, 0, 1)   Log Likelihood                -497.547
# Date:                Fri, 25 Apr 2025   AIC                           1017.095
# Time:                        21:50:49   BIC                           1066.493
# Sample:                             0   HQIC                          1036.243
#                                 - 659
# Covariance Type:                  opg
# ...
#                                 coef    std err          z      P>|z|      [0.025      0.975]
# ---------------------------------------------------------------------------------------------
# Previous_GDP               -1.78e-06   1.81e-23  -9.83e+16      0.000   -1.78e-06   -1.78e-06
# Previous_EUR_Cash         -9.978e-05   3.28e-25  -3.04e+20      0.000   -9.98e-05   -9.98e-05
# ...

# %% [markdown]
# # Predict

# %%
vcb_prediction = vcb_sarimax.predict(
    n_periods=1,
    X=vcb_future
)
vcb_prediction
# Out:
# 833    73.586358
# dtype: float64

# %%
bid_prediction = bid_sarimax.predict(
    n_periods=1,
    X=bid_future
)
bid_prediction
# Out:
# 777    44.071683
# dtype: float64

# %%
tcb_prediction = tcb_sarimax.predict(
    n_periods=1,
    X=tcb_future
)
tcb_prediction
# Out:
# 659    25.662682
# dtype: float64
